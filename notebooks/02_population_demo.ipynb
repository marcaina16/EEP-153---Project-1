# %%
import os, sys
sys.path.insert(0, os.path.abspath(".."))

# %%
import logging
logging.getLogger("shelved_cache.persistent_cache").setLevel(logging.ERROR)

# %%
from src.population import population, population_dataframe
from src.pyramid import population_pyramid

# %%
population(2000, "Total", (0,14), "WLD")
# Out:
# 1872410877.0

# %%
pop = population_dataframe(["WLD","USA","BRA"], range(2000,2005))
pop.head()
# Out:
#             index  pop_00_14_male  pop_00_14_female  pop_00_14_total  \
# place year
# BRA   2000      4      26421817.0        25580429.0       52002245.0
#       2001      3      26256657.0        25408273.0       51664930.0
#       2002      2      26072199.0        25217159.0       51289358.0
#       2003      1      25872569.0        25011067.0       50883636.0
#       2004      0      25669298.0        24801649.0       50470948.0
#
#             pop_15_64_male  pop_15_64_female  pop_15_64_total  \
# place year
# BRA   2000      56191793.0        56856984.0      113048777.0
#       2001      57334334.0        58032216.0      115366551.0
#       2002      58442995.0        59184459.0      117627454.0
#       2003      59511126.0        60304918.0      119816044.0
#       2004      60534060.0        61385870.0      121919930.0
#
#             pop_65_100_male  pop_65_100_female  pop_65_100_total
# place year
# BRA   2000        3841217.0          5126043.0         8967260.0
# ...

# %%
population_pyramid(pop.loc[("WLD",2000)], title="World (2000)")
